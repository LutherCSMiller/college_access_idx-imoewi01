# %% [markdown]
# # The College Accessability Index
#
#
# From the Malcolm Gladwell podcast -- revisionist history on Vassar versus Bodoin
#
# * [The Article](http://www.nytimes.com/2015/09/17/upshot/college-access-index-2015-the-details.html?_r=0)
#
# * [The IPEDS website for data](https://nces.ed.gov/ipeds/datacenter/DataFiles.aspx)
#
#
#
#
# We then multiplied this graduation rate by the share of first-year students who received Pell grants in recent years. This number led to one half of a college’s index number. The other half came from the average price — tuition, fees, room and board, net of financial aid — that the college charged students from families with between $30,000 and $75,000 in annual income.
#
# The overall goal remains the same: examining economic diversity at colleges where graduation is the norm.
#
# Second, we tried to give colleges credit only for those lower-income students who graduate rather than all those who enroll. To do so, we asked colleges to provide their graduation rate for students receiving Pell grants, the federal financial-aid program that typically helps students coming from the bottom 40 percent of the income distribution.

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from ggplot import *
import seaborn as sbn
from altair import *

# %%
fa = pd.read_excel('sfa1314.xlsx')
fa.head()
# Out:
#    UNITID XSCUGRAD  SCUGRAD XSCUGFFN  SCUGFFN XSCUGFFP  SCUGFFP XSCFA2  \
# 0  100654        R     4051        R     1066        R       26      R
# 1  100663        R    11542        R     1732        R       15      R
# 2  100690        R      322        R        3        R        1      R
# 3  100706        R     5696        R      638        R       11      R
# 4  100724        R     5356        R     1520        R       28      R
#
#      SCFA2 XSCFA1N   ...     XNPT410  NPT410  XNPT420  NPT420  XNPT430 NPT430  \
# 0   4051.0       R   ...           A     NaN        A     NaN        A    NaN
# 1  11542.0       R   ...           A     NaN        A     NaN        A    NaN
# 2    322.0       R   ...           R  6332.0        R  8364.0        A    NaN
# 3   5696.0       R   ...           A     NaN        A     NaN        A    NaN
# 4   5356.0       R   ...           A     NaN        A     NaN        A    NaN
#
#    XNPT440 NPT440  XNPT450 NPT450
# 0        A    NaN        A      NaN
# 1        A    NaN        A      NaN
# 2        A    NaN        A      NaN
# 3        A    NaN        A      NaN
# 4        A    NaN        A      NaN
#
# [5 rows x 647 columns]

# %%
fa.columns
# Out:
# Index(['UNITID', 'XSCUGRAD', 'SCUGRAD', 'XSCUGFFN', 'SCUGFFN', 'XSCUGFFP',
#        'SCUGFFP', 'XSCFA2', 'SCFA2', 'XSCFA1N',
#        ...
#        'XNPT410', 'NPT410', 'XNPT420', 'NPT420', 'XNPT430', 'NPT430',
#        'XNPT440', 'NPT440', 'XNPT450', 'NPT450  '],
#       dtype='object', length=647)

# %%
hd = pd.read_excel('hd2014.xlsx')

# %%
hd.head()
# Out:
#    UNITID                               INSTNM  \
# 0  100636   Community College of the Air Force
# 1  100654             Alabama A & M University
# 2  100663  University of Alabama at Birmingham
# 3  100690                   Amridge University
# 4  100706  University of Alabama in Huntsville
#
#                              ADDR        CITY STABBR         ZIP  FIPS  \
# 0               100 S Turner Blvd  Montgomery     AL  36114-3011     1
# 1            4900 Meridian Street      Normal     AL       35762     1
# 2  Administration Bldg Suite 1070  Birmingham     AL  35294-0110     1
# 3                  1200 Taylor Rd  Montgomery     AL  36117-3553     1
# 4                 301 Sparkman Dr  Huntsville     AL       35899     1
#
#    OBEREG                   CHFNM    CHFTITLE   ...    F1SYSTYP  \
# 0       0         Michael Artelli  Commandant   ...          -1
# 1       5  Dr. Andrew Hugine, Jr.   President   ...           2
# 2       5            Ray L. Watts   President   ...           1
# 3       5          Michael Turner   President   ...           2
# 4       5    Robert A. Altenkirch   President   ...           1
#
#                            F1SYSNAM  F1SYSCOD  COUNTYCD    COUNTYNM CNGDSTCD  \
# 0                                          -1      1101  Montgomery      102
# 1                                          -2      1089     Madison      105
# 2  The University of Alabama System    101050      1073   Jefferson      107
# 3                                          -2      1101  Montgomery      102
# 4  The University of Alabama System    101050      1089     Madison      105
#
#     LONGITUD   LATITUDE DFRCGID DFRCUSCG
# 0 -86.244548  32.406138      -1       -1
# 1 -86.568502  34.783368     131        1
# 2 -86.809170  33.502230     119        1
# 3 -86.174010  32.362609     232        2
# 4 -86.638420  34.722818     119        2
#
# [5 rows x 69 columns]

# %%
ggplot(fa, aes(x='PGRNT_P')) + geom_histogram(bins=20, color='blue')
# Out:
# <ggplot: (8731474622770)>

# %%
hd = hd[(hd.STABBR=='IA') | (hd.STABBR=='MN')]

# %%
fa[fa.UNITID==153834][['UFLOANP','SCUGRAD','SCUGFFN','PGRNT_P']]
# Out:
#       UFLOANP  SCUGRAD  SCUGFFN  PGRNT_P
# 1232       67     2466      627     21.0

# %%
 df = pd.DataFrame({"A":["a","b","c","a"], "B":[6,5,4,9]})

# %%
ggplot(df, aes(x="A")) + geom_bar()
# Out:
# <ggplot: (8731474622735)>

# %%
df.A = df.A.astype('category')

# %%
df.A
# Out:
# 0    a
# 1    b
# 2    c
# 3    a
# Name: A, dtype: category
# Categories (3, object): [a, b, c]

# %%
df.A
# Out:
# 0    a
# 1    b
# 2    c
# 3    a
# Name: A, dtype: category
# Categories (3, object): [a, b, c]

# %%
df.C = df.A.copy()

# %%
df.C.sort_values(inplace=True)

# %%
df.D = df.C.cat.as_ordered()

# %%
df['D'] = df.C.cat.as_ordered()

# %%
#
df.D.cat.set_categories(['c','b','a'], ordered=True)
# Out:
# 0    a
# 3    a
# 1    b
# 2    c
# dtype: category
# Categories (3, object): [c < b < a]

# %%
df['D'] = df.D.cat.set_categories(['c','b','a'], ordered=True)

# %%
df['D']
# Out:
# 0    a
# 1    b
# 2    c
# 3    a
# Name: D, dtype: category
# Categories (3, object): [c < b < a]

# %%
#Net price for families with income between 75,000 and 48,000
# Out:
#       UNITID XSCUGRAD  SCUGRAD XSCUGFFN  SCUGFFN XSCUGFFP  SCUGFFP XSCFA2  \
# 0     100654        R     4051        R     1066        R       26      R
# 1     100663        R    11542        R     1732        R       15      R
# 2     100690        R      322        R        3        R        1      R
# 3     100706        R     5696        R      638        R       11      R
# 4     100724        R     5356        R     1520        R       28      R
# 5     100751        R    29440        R     6428        R       22      R
# 6     100760        R     1906        R      480        R       25      R
# 7     100812        R     3175        R        0        Z        0      R
# 8     100830        R     4334        R      589        R       14      R
# 9     100858        R    19799        R     3696        R       19      R
# 10    100937        R     1177        R      352        R       30      R
# 11    101028        R     1837        R      333        R       18      R
# 12    101073        R      600        R      147        R       25      R
# 13    101116        R      599        R       27        R        5      R
# 14    101143        R     2333        R      340        R       15      R
# 15    101161        R     4362        R     1078        R       25      R
# 16    101189        R     2617        R      287        R       11      R
# 17    101240        R     5797        R     1143        R       20      R
# 18    101277        R      152        R       70        R       46      A
# 19    101286        R     4686        R      838        R       18      R
# 20    101295        R     5281        R      997        R       19      R
# 21    101301        R     1745        R      371        R       21      R
# 22    101365        R      318        R       25        R        8      R
# 23    101435        R     1110        R      261        R       24      R
# 24    101453        R       69        R        7        R       10      R
# 25    101462        R     1383        R      142        R       10      R
# 26    101471        R      513        R      246        R       48      R
# 27    101480        R     7588        R     1142        R       15      R
# 28    101499        R     1091        R      246        R       23      R
# 29    101505        R     8542        R     1053        R       12      R
# ...      ...      ...      ...      ...      ...      ...      ...    ...
# 7045  484871        R       72        R       22        R       31      R
# 7046  484899        R      178        R      114        R       64      A
# 7047  484905        R     1845        R      121        R        7      R
# 7048  484923        R       55        R        6        R       11      A
# 7049  484950        R       67        R        7        R       10      A
# 7050  484996        R       88        R       88        R      100      A
# 7051  485014        R       31        R       11        R       35      A
# 7052  485032        R       73        R       19        R       26      A
# 7053  485041        R       32        R        8        R       25      A
# 7054  485087        R       57        R       32        R       56      A
# 7055  485111        R     7109        R     1549        R       22      R
# 7056  485120        R      310        R        0        Z        0      A
# 7057  485139        R      113        R       61        R       54      A
# 7058  485166        R       31        R       31        R      100      A
# 7059  485184        R       29        R       19        R       66      A
# 7060  485193        R        7        R        7        R      100      A
# 7061  485236        R       22        R        6        R       27      A
# 7062  485245        R       26        R       18        R       69      A
# 7063  485254        R       20        R        9        R       45      A
# 7064  485263        R      980        R      265        R       27      R
# 7065  485281        R      190        R        1        R        1      R
# 7066  485306        R       66        R       66        R      100      A
# 7067  485342        R      373        R       80        R       21      R
# 7068  485351        R      234        R      113        R       48      R
# 7069  485379        R      137        R       27        R       20      A
# 7070  485388        R      197        R       75        R       38      A
# 7071  485397        R       92        R       54        R       59      A
# 7072  485412        R       81        R       31        R       38      A
# 7073  485421        R       52        R       40        R       77      R
# 7074  485458        R     2422        R      155        R        6      R
#
#         SCFA2 XSCFA1N   ...     XNPT410   NPT410  XNPT420   NPT420  XNPT430  \
# 0      4051.0       R   ...           A      NaN        A      NaN        A
# 1     11542.0       R   ...           A      NaN        A      NaN        A
# 2       322.0       R   ...           R   6332.0        R   8364.0        A
# 3      5696.0       R   ...           A      NaN        A      NaN        A
# 4      5356.0       R   ...           A      NaN        A      NaN        A
# 5     29440.0       R   ...           A      NaN        A      NaN        A
# 6      1906.0       R   ...           A      NaN        A      NaN        A
# 7      3175.0       R   ...           A      NaN        A      NaN        A
# 8      4334.0       R   ...           A      NaN        A      NaN        A
# 9     19799.0       R   ...           A      NaN        A      NaN        A
# 10     1177.0       R   ...           R  18392.0        R  19152.0        R
# 11     1837.0       R   ...           A      NaN        A      NaN        A
# 12      600.0       R   ...           R  11475.0        R  11818.0        R
# 13      599.0       R   ...           R  23435.0        R  24192.0        R
# 14     2333.0       R   ...           A      NaN        A      NaN        A
# 15     4362.0       R   ...           A      NaN        A      NaN        A
# 16     2617.0       R   ...           R  17140.0        R  18637.0        R
# 17     5797.0       R   ...           A      NaN        A      NaN        A
# 18        NaN       A   ...           R   5153.0        R   6828.0        R
# 19     4686.0       R   ...           A      NaN        A      NaN        A
# 20     5281.0       R   ...           A      NaN        A      NaN        A
# 21     1745.0       R   ...           A      NaN        A      NaN        A
# 22      318.0       R   ...           R  23271.0        A      NaN        A
# 23     1110.0       R   ...           R  16028.0        R  17144.0        R
# 24       69.0       R   ...           R  10373.0        R   9806.0        R
# 25     1383.0       R   ...           A      NaN        A      NaN        A
# 26      513.0       R   ...           A      NaN        A      NaN        A
# 27     7588.0       R   ...           A      NaN        A      NaN        A
# 28     1091.0       R   ...           A      NaN        A      NaN        A
# 29     8542.0       R   ...           A      NaN        A      NaN        A
# ...       ...     ...   ...         ...      ...      ...      ...      ...
# 7045     72.0       R   ...           A      NaN        A      NaN        A
# 7046      NaN       A   ...           A      NaN        A      NaN        A
# 7047   1845.0       R   ...           A      NaN        A      NaN        A
# 7048      NaN       A   ...           A      NaN        A      NaN        A
# 7049      NaN       A   ...           A      NaN        A      NaN        A
# 7050      NaN       A   ...           A      NaN        A      NaN        A
# 7051      NaN       A   ...           A      NaN        A      NaN        A
# 7052      NaN       A   ...           A      NaN        A      NaN        A
# 7053      NaN       A   ...           A      NaN        A      NaN        A
# 7054      NaN       A   ...           A      NaN        A      NaN        A
# 7055   7109.0       R   ...           A      NaN        A      NaN        A
# 7056      NaN       A   ...           A      NaN        A      NaN        A
# 7057      NaN       A   ...           A      NaN        A      NaN        A
# 7058      NaN       A   ...           A      NaN        A      NaN        A
# 7059      NaN       A   ...           A      NaN        A      NaN        A
# 7060      NaN       A   ...           A      NaN        A      NaN        A
# 7061      NaN       A   ...           A      NaN        A      NaN        A
# 7062      NaN       A   ...           A      NaN        A      NaN        A
# 7063      NaN       A   ...           A      NaN        A      NaN        A
# 7064    980.0       R   ...           R  18168.0        R  19433.0        R
# 7065    190.0       R   ...           A      NaN        A      NaN        A
# 7066      NaN       A   ...           A      NaN        A      NaN        A
# 7067    373.0       R   ...           A      NaN        A      NaN        A
# 7068    234.0       R   ...           A      NaN        A      NaN        A
# 7069      NaN       A   ...           A      NaN        A      NaN        A
# 7070      NaN       A   ...           A      NaN        A      NaN        A
# 7071      NaN       A   ...           A      NaN        A      NaN        A
# 7072      NaN       A   ...           A      NaN        A      NaN        A
# 7073     52.0       R   ...           A      NaN        A      NaN        A
# 7074   2422.0       R   ...           A      NaN        A      NaN        A
#
#        NPT430  XNPT440   NPT440  XNPT450 NPT450
# 0         NaN        A      NaN        A      NaN
# 1         NaN        A      NaN        A      NaN
# 2         NaN        A      NaN        A      NaN
# 3         NaN        A      NaN        A      NaN
# 4         NaN        A      NaN        A      NaN
# 5         NaN        A      NaN        A      NaN
# 6         NaN        A      NaN        A      NaN
# 7         NaN        A      NaN        A      NaN
# 8         NaN        A      NaN        A      NaN
# 9         NaN        A      NaN        A      NaN
# 10    20579.0        R  22578.0        R  28500.0
# 11        NaN        A      NaN        A      NaN
# 12    11884.0        R  16386.0        A      NaN
# 13    26822.0        R  27863.0        R  28156.0
# 14        NaN        A      NaN        A      NaN
# 15        NaN        A      NaN        A      NaN
# 16    18741.0        R  19433.0        R  19795.0
# 17        NaN        A      NaN        A      NaN
# 18     7270.0        A      NaN        A      NaN
# 19        NaN        A      NaN        A      NaN
# 20        NaN        A      NaN        A      NaN
# 21        NaN        A      NaN        A      NaN
# 22        NaN        A      NaN        A      NaN
# 23    20181.0        R  20653.0        R  21068.0
# 24    15035.0        R  13050.0        A      NaN
# 25        NaN        A      NaN        A      NaN
# 26        NaN        A      NaN        A      NaN
# 27        NaN        A      NaN        A      NaN
# 28        NaN        A      NaN        A      NaN
# 29        NaN        A      NaN        A      NaN
# ...       ...      ...      ...      ...      ...
# 7045      NaN        A      NaN        A      NaN
# 7046      NaN        A      NaN        A      NaN
# 7047      NaN        A      NaN        A      NaN
# 7048      NaN        A      NaN        A      NaN
# 7049      NaN        A      NaN        A      NaN
# 7050      NaN        A      NaN        A      NaN
# 7051      NaN        A      NaN        A      NaN
# 7052      NaN        A      NaN        A      NaN
# 7053      NaN        A      NaN        A      NaN
# 7054      NaN        A      NaN        A      NaN
# 7055      NaN        A      NaN        A      NaN
# 7056      NaN        A      NaN        A      NaN
# 7057      NaN        A      NaN        A      NaN
# 7058      NaN        A      NaN        A      NaN
# 7059      NaN        A      NaN        A      NaN
# 7060      NaN        A      NaN        A      NaN
# 7061      NaN        A      NaN        A      NaN
# 7062      NaN        A      NaN        A      NaN
# 7063      NaN        A      NaN        A      NaN
# 7064  22038.0        R  16994.0        R  17623.0
# 7065      NaN        A      NaN        A      NaN
# 7066      NaN        A      NaN        A      NaN
# 7067      NaN        A      NaN        A      NaN
# 7068      NaN        A      NaN        A      NaN
# 7069      NaN        A      NaN        A      NaN
# 7070      NaN        A      NaN        A      NaN
# 7071      NaN        A      NaN        A      NaN
# 7072      NaN        A      NaN        A      NaN
# 7073      NaN        A      NaN        A      NaN
# 7074      NaN        A      NaN        A      NaN
#
# [7075 rows x 647 columns]

# %%
final = pd.merge(hd, fa, left_on='UNITID',right_on='UNITID')

# %%
final.fillna(0)
# Out:
#      UNITID                                             INSTNM  \
# 0    125231                                  Walden University
# 1    152798                                      Allen College
# 2    152822                            AIB College of Business
# 3    152992                             Briar Cliff University
# 4    153001                             Buena Vista University
# 5    153074                              Capri College-Dubuque
# 6    153083                         Capri College-Cedar Rapids
# 7    153092       American College of Hairstyling-Cedar Rapids
# 8    153108                                    Central College
# 9    153126                                  Clarke University
# 10   153144                                        Coe College
# 11   153162                                    Cornell College
# 12   153171                 Iowa School of Beauty-Marshalltown
# 13   153214                  Des Moines Area Community College
# 14   153241                                Divine Word College
# 15   153250                                      Dordt College
# 16   153269                                   Drake University
# 17   153278                              University of Dubuque
# 18   153296                        Ellsworth Community College
# 19   153302                               Emmaus Bible College
# 20   153311            Eastern Iowa Community College District
# 21   153320  Faith Baptist Bible College and Theological Se...
# 22   153339          Faust Institute of Cosmetology-Storm Lake
# 23   153366                        Graceland University-Lamoni
# 24   153375                              Grand View University
# 25   153384                                   Grinnell College
# 26   153409                Kaplan University-Mason City Campus
# 27   153418              Kaplan University-Cedar Rapids Campus
# 28   153427                         Hamilton Technical College
# 29   153445                          Hawkeye Community College
# ..      ...                                                ...
# 195  447342                 Regency Beauty Institute-Ridgedale
# 196  447670             Minnesota School of Business-Rochester
# 197  449214                    Regency Beauty Institute-Duluth
# 198  451194                 Carlson College of Massage Therapy
# 199  451769                Minnesota School of Business-Blaine
# 200  451954                      ITT Technical Institute-Clive
# 201  453570                  Empire Beauty School-Eden Prairie
# 202  454616              Institute of Production and Recording
# 203  455585              Minnesota School of Business-Moorhead
# 204  456135              Empire Beauty School-Spring Lake Park
# 205  456782             Minnesota School of Business-Elk River
# 206  456834                       Globe University-Minneapolis
# 207  456959                  University of Minnesota-Rochester
# 208  457651  CenterPoint Massage and Shiatsu Therapy School...
# 209  457679                       Avalon School of Cosmetology
# 210  458742             Minnesota School of Business-Lakeville
# 211  459426                        Nova Academy of Cosmetology
# 212  459620               ITT Technical Institute-Cedar Rapids
# 213  460561                  Park Avenue School of Cosmetology
# 214  461546                    Rochester School of Hair Design
# 215  461731           The Salon Professional Academy-Iowa City
# 216  470870            ITT Technical Institute-Brooklyn Center
# 217  474881                        Minneapolis Media Institute
# 218  475015                         Aveda Institute-Des Moines
# 219  475291              Sanford-Brown College-Brooklyn Center
# 220  478005            National American University-Burnsville
# 221  480170    Minnesota School of Cosmetology-Plymouth Campus
# 222  480499                                  Shiloh University
# 223  482343             National American University-Rochester
# 224  482529                         DeVry University-Minnesota
#
#                                              ADDR              CITY STABBR  \
# 0          100 Washington Avenue South, Suite 900       Minneapolis     MN
# 1                                   1990 Heath St          Waterloo     IA
# 2                                2500 Fleur Drive        Des Moines     IA
# 3                             3303 Rebecca Street        Sioux City     IA
# 4                                    610 W 4th St        Storm Lake     IA
# 5                                     395 Main St           Dubuque     IA
# 6                      2945 Williams Parkway S.W.      Cedar Rapids     IA
# 7                               1531 First Ave SE      Cedar Rapids     IA
# 8                                  812 University             Pella     IA
# 9                                  1550 Clarke Dr           Dubuque     IA
# 10                              1220 First Ave NE      Cedar Rapids     IA
# 11                               600 First St. SW      Mount Vernon     IA
# 12                                112 Nicholas Dr      Marshalltown     IA
# 13                               2006 Ankeny Blvd            Ankeny     IA
# 14                               102 Jacoby Dr SW           Epworth     IA
# 15                                 498 4th Ave NE      Sioux Center     IA
# 16                         2507 University Avenue        Des Moines     IA
# 17                            2000 University Ave           Dubuque     IA
# 18                               1100 College Ave        Iowa Falls     IA
# 19                                 2570 Asbury Rd           Dubuque     IA
# 20                                 306 W River Dr         Davenport     IA
# 21                                 1900 NW 4th St            Ankeny     IA
# 22                            1290 N. Lake Avenue        Storm Lake     IA
# 23                             1 University Place            Lamoni     IA
# 24                             1200 Grandview Ave        Des Moines     IA
# 25                               1121 Park Street          Grinnell     IA
# 26                  Plaza West 2570 4th Street SW        Mason City     IA
# 27                       3165 Edgewood Parkway SW      Cedar Rapids     IA
# 28                                 1011 E 53rd St         Davenport     IA
# 29                               1501 E Orange Rd          Waterloo     IA
# ..                                            ...               ...    ...
# 195              12993 Ridgedale Drive, Suite 103        Minnetonka     MN
# 196                      2521 Pennington Drive NW         Rochester     MN
# 197             5115 Burning Tree Road, Suite 308            Duluth     MN
# 198                          11809 Country Rd X28           Anamosa     IA
# 199                     3680 Pheasant Ridge Dr NE            Blaine     MN
# 200                     1860 NW 118th St, Ste 110             Clive     IA
# 201                        964 Prairie Center Dr.      Eden Prairie     MN
# 202                  300 North 1st Ave, Suite 500       Minneapolis     MN
# 203                        2777 34th Street South          Moorhead     MN
# 204                           8205 University Ave  Spring Lake Park     MN
# 205                            11500 193rd Ave NW         Elk River     MN
# 206     IDS Center, 80 South 8th Street, Suite 51       Minneapolis     MN
# 207     300 University Square  111 South Broadway         Rochester     MN
# 208                         5300 West 35th Street     St Louis Park     MN
# 209                            1428 N McMillan St       Worthington     MN
# 210                            17685 Juniper Path         Lakeville     MN
# 211                         1629 N Broadway Ste 7         Rochester     MN
# 212                              3735 Queen Ct SW      Cedar Rapids     IA
# 213                                306 Main Ave S       Park Rapids     MN
# 214                         4229 Highway 52 North         Rochester     MN
# 215                         1550 South 1st Avenue         Iowa City     IA
# 216             6120 Earle Brown Drive, Suite 100   Brooklyn Center     MN
# 217                            4100 W 76th Street             Edina     MN
# 218               6905 Mills Civic Pkwy Suite 120   West Des Moines     IA
# 219                           5951 Earle Brown Dr   Brooklyn Center     MN
# 220                      513 West Travelers Trail        Burnsville     MN
# 221                          1425 County Rd 101 N          Plymouth     MN
# 222                                 100 Shiloh DR            Kalona     IA
# 223  3906 East Frontage Road Northwest Highway 52         Rochester     MN
# 224                  7700 France Ave S., Ste. 575             Edina     MN
#
#             ZIP  FIPS  OBEREG                         CHFNM  \
# 0         55401    27       4                  Cynthia Baum
# 1    50703-1999    19       4                  Jerry Durham
# 2    50321-1799    19       4                Nancy Williams
# 3         51104    19       4               Beverly Wharton
# 4         50588    19       4             Frederick V Moore
# 5    52004-0873    19       4                Charles Fiegen
# 6         52404    19       4                Charles Fiegen
# 7         52402    19       4                    T L Millis
# 8         50219    19       4                   Mark Putnam
# 9    52001-3198    19       4  Joanne M. Burrows, SC, Ph.D.
# 10   52402-5092    19       4                David McInally
# 11   52314-1098    19       4                Jonathan Brand
# 12        50158    19       4                   Mark Oswald
# 13   50023-3993    19       4              Robert J. Denson
# 14        52045    19       4               Timothy Lenchak
# 15   51250-1697    19       4                 Erik Hoekstra
# 16   50311-4505    19       4               David E Maxwell
# 17        52001    19       4             Jeffrey F Bullock
# 18        50126    19       4             Christopher Duree
# 19   52001-3096    19       4                   Philip Boom
# 20   52801-1221    19       4                  Don Doucette
# 21   50023-2152    19       4             Ernest J. Schmidt
# 22        50588    19       4                 Justin Latham
# 23        50140    19       4              Dr. John Sellars
# 24        50316    19       4               Kent L. Henning
# 25   50112-1690    19       4             Raynard S Kington
# 26        50401    19       4                Julie Valencia
# 27        52404    19       4                  Susan Spivey
# 28        52807    19       4             Maryanne Hamilton
# 29        50701    19       4                   Linda Allen
# ..          ...   ...     ...                           ...
# 195       55305    27       4                   Joe Gaylord
# 196       55901    27       4              Kenneth McCarthy
# 197       55811    27       4                   Joe Gaylord
# 198       52205    19       4               Christina Rider
# 199       55449    27       4              Kenneth McCarthy
# 200       50325    19       4                   Keri Nelson
# 201       55344    27       4                Michael Bouman
# 202       55401    27       4              Kenneth McCarthy
# 203       56560    27       4              Kenneth McCarthy
# 204       55432    27       4                Michael Bouman
# 205       55330    27       4              Kenneth McCarthy
# 206       55402    27       4              Kenneth McCarthy
# 207       55904    27       4             Stephen Lehmkuhle
# 208       55416    27       4                   Cari Pelava
# 209       56187    27       4            Kimberly Schroeder
# 210       55044    27       4              Kenneth McCarthy
# 211       55906    27       4             Michelle Forstner
# 212       52404    19       4                     Tim Evans
# 213  56470-1551    27       4                Kristine Walsh
# 214  55901-4310    27       4               Lisa J Peterson
# 215  52240-6083    19       4             Melissa MMoreland
# 216  55430-4100    27       4                  Staci Hitzke
# 217       55435    27       4                    Kathy Doty
# 218       50266    19       4                Doug Van Polen
# 219       55430    27       4               Sheila Malewska
# 220  55337-2548    27       4          Dr. Jerry Gallentine
# 221       55447    27       4              Kenneth McCarthy
# 222       52247    19       4            Christopher Reeves
# 223  55901-4001    27       4          Dr. Jerry Gallentine
# 224       55435    27       4            Stephanie Grgurich
#
#                            CHFTITLE   ...     XNPT410   NPT410  XNPT420  \
# 0                         President   ...           A      0.0        A
# 1                        Chancellor   ...           A      0.0        A
# 2                         President   ...           R  10877.0        R
# 3                         President   ...           R  15229.0        R
# 4                         President   ...           R  15482.0        R
# 5                             Owner   ...           R   9142.0        R
# 6                             Owner   ...           R   8752.0        R
# 7                         President   ...           R   8173.0        R
# 8                         President   ...           R  15598.0        R
# 9                         President   ...           R  15959.0        R
# 10                        President   ...           R  14824.0        R
# 11                        President   ...           R  13116.0        R
# 12                        President   ...           R   6782.0        R
# 13                  President & CEO   ...           A      0.0        A
# 14                        President   ...           R   6010.0        R
# 15                        President   ...           R  19641.0        R
# 16                        President   ...           R  21124.0        R
# 17                        President   ...           R  14678.0        R
# 18                       Chancellor   ...           A      0.0        A
# 19                        President   ...           R  13718.0        R
# 20                       Chancellor   ...           A      0.0        A
# 21                Interim President   ...           R  14874.0        R
# 22                   Owner/Director   ...           R   5743.0        R
# 23                        President   ...           R  11095.0        R
# 24                        President   ...           R  14128.0        R
# 25                        President   ...           R   8370.0        R
# 26               Executive Director   ...           R  18127.0        R
# 27                 Campus President   ...           R  19217.0        R
# 28                        President   ...           R  13803.0        R
# 29                        President   ...           A      0.0        A
# ..                              ...   ...         ...      ...      ...
# 195                 President & CEO   ...           R  22205.0        A
# 196         Chief Financial Officer   ...           R  19182.0        R
# 197                 President & CEO   ...           R  22022.0        A
# 198  Chief Operating Officer, Owner   ...           R  10403.0        A
# 199         Chief Financial Officer   ...           R  17924.0        R
# 200                        Director   ...           R  22622.0        R
# 201                       President   ...           R  10622.0        R
# 202         Chief Financial Officer   ...           R  29376.0        R
# 203         Chief Financial Officer   ...           R  24494.0        R
# 204                   President/COO   ...           R  11013.0        R
# 205         Chief Financial Officer   ...           R  17637.0        R
# 206         Chief Financial Officer   ...           R  25050.0        A
# 207                      Chancellor   ...           A      0.0        A
# 208                        Director   ...           R  17122.0        R
# 209                        Director   ...           R   6844.0        A
# 210         Chief Financial Officer   ...           R  18388.0        R
# 211                          C.E.O.   ...           R  14151.0        R
# 212                        Director   ...           A      0.0        A
# 213                  Director/Owner   ...           R   6962.0        A
# 214                       President   ...           R  11032.0        R
# 215                       President   ...           R  12725.0        R
# 216                        Director   ...           R  19922.0        R
# 217                 Campus Director   ...           R  24538.0        R
# 218                           Owner   ...           R  16635.0        R
# 219                       President   ...           R  19852.0        R
# 220            University President   ...           A      0.0        A
# 221         Chief Financial Officer   ...           R   7468.0        R
# 222                       President   ...           A      0.0        A
# 223            University President   ...           A      0.0        A
# 224                 Campus Director   ...           R  22772.0        R
#
#       NPT420 XNPT430   NPT430 XNPT440   NPT440 XNPT450 NPT450
# 0        0.0       A      0.0       A      0.0       A      0.0
# 1        0.0       A      0.0       R  26946.0       A      0.0
# 2     8290.0       R  12350.0       R  13941.0       R  17068.0
# 3    17191.0       R  18740.0       R  20689.0       R  20142.0
# 4    15095.0       R  16855.0       R  18280.0       R  20188.0
# 5     9512.0       R  11200.0       R  13000.0       R  13000.0
# 6    10734.0       R  13104.0       R  13804.0       R  13804.0
# 7     8426.0       R   8146.0       A      0.0       A      0.0
# 8    17378.0       R  18235.0       R  23105.0       R  26479.0
# 9    17250.0       R  19371.0       R  23402.0       R  27013.0
# 10   15571.0       R  18487.0       R  20281.0       R  23562.0
# 11   13913.0       R  14236.0       R  20975.0       R  26867.0
# 12    6483.0       R  11566.0       R   9816.0       R   7015.0
# 13       0.0       A      0.0       A      0.0       A      0.0
# 14   12634.0       A      0.0       A      0.0       A      0.0
# 15   19186.0       R  21708.0       R  23830.0       R  26058.0
# 16   22123.0       R  23238.0       R  25564.0       R  28441.0
# 17   15097.0       R  16562.0       R  17801.0       R  18173.0
# 18       0.0       A      0.0       A      0.0       A      0.0
# 19   11770.0       R  14784.0       R  18867.0       R  19282.0
# 20       0.0       A      0.0       A      0.0       A      0.0
# 21   13431.0       R  14317.0       R  20186.0       R  21579.0
# 22    6466.0       R  10563.0       R  11061.0       A      0.0
# 23   12292.0       R  13562.0       R  16685.0       R  18301.0
# 24   15242.0       R  16723.0       R  18707.0       R  21321.0
# 25   10117.0       R  15227.0       R  22540.0       R  32655.0
# 26   19947.0       A      0.0       A      0.0       R  24641.0
# 27   18213.0       R  19071.0       R  25653.0       A      0.0
# 28   15229.0       R  15940.0       R  16933.0       R  18218.0
# 29       0.0       A      0.0       A      0.0       A      0.0
# ..       ...     ...      ...     ...      ...     ...      ...
# 195      0.0       A      0.0       A      0.0       A      0.0
# 196  19818.0       R  22565.0       R  26874.0       R  25911.0
# 197      0.0       A      0.0       A      0.0       A      0.0
# 198      0.0       A      0.0       A      0.0       A      0.0
# 199  19473.0       R  22770.0       A      0.0       R  24676.0
# 200  23267.0       R  26076.0       R  27598.0       A      0.0
# 201  13095.0       R  12259.0       R  16486.0       R  16486.0
# 202  29826.0       R  32878.0       R  35455.0       R  35046.0
# 203  25299.0       R  26565.0       R  28254.0       R  30593.0
# 204  14020.0       R  14906.0       R  16322.0       A      0.0
# 205  22183.0       R  17487.0       R  22108.0       R  24522.0
# 206      0.0       A      0.0       A      0.0       A      0.0
# 207      0.0       A      0.0       A      0.0       A      0.0
# 208  19323.0       R  18316.0       R  21958.0       A      0.0
# 209      0.0       A      0.0       A      0.0       A      0.0
# 210   9733.0       R  15575.0       R  23477.0       A      0.0
# 211  15280.0       R  16019.0       R  19059.0       A      0.0
# 212      0.0       A      0.0       A      0.0       A      0.0
# 213      0.0       A      0.0       A      0.0       A      0.0
# 214  12096.0       A      0.0       A      0.0       A      0.0
# 215  14854.0       R  16235.0       R  16235.0       R  16235.0
# 216  22289.0       R  23755.0       R  27089.0       A      0.0
# 217  27016.0       R  28410.0       R  30359.0       R  30359.0
# 218  17241.0       R  17647.0       R  18941.0       R  18941.0
# 219  21227.0       A      0.0       A      0.0       A      0.0
# 220      0.0       A      0.0       A      0.0       A      0.0
# 221   7485.0       R   9224.0       R  10481.0       R  10481.0
# 222      0.0       A      0.0       A      0.0       A      0.0
# 223      0.0       A      0.0       A      0.0       A      0.0
# 224  23170.0       R  21426.0       A      0.0       A      0.0
#
# [225 rows x 715 columns]

# %%
final = final.sort_values('NPT431')

# %%
Chart(final).mark_bar().encode(
                            x=X('NPT431', axis=Axis(title='Net Cost for Income between 48k and 75k')),
                            y=Y('INSTNM', sort=SortField(field='NPT431',order='descending')))
# Out:
# <div class="vega-embed" id="4fb47af5-9d5d-4067-8a23-c1b06557f1ea"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>
